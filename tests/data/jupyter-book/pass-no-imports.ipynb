# %% [markdown]
# # Test Notebook: No Imports
#
# This notebook should **PASS** the imports check because it has no import statements at all.

# %%
# Simple calculations without imports
x = 5
y = 10
result = x + y

# %% [markdown]
# ## More Calculations

# %%
# More simple calculations
squared = result**2
doubled = result * 2

# %%
# Final result
final = squared + doubled
