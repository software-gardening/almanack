# %% [markdown]
# import all deps (this should not also trigger)

# %%
import pandas as pd

# %%
# import all datasets (THIS SHOULD NOT TRIGGER A WARNING)
path = "some/unknown/path"
df = pd.read_csv(path)

# %% [markdown]
# import pandas as pd (This should not also tigger since it's in a markdown cell)

# %%
# importing all other dataset
