# %% [markdown]
# # Test Notebook: Only Markdown Cells
#
# This notebook should **PASS** because it only contains markdown cells with no code cells at all.

# %% [markdown]
# ## Section 1
#
# This is just documentation.
#
# Some important points:
# - Point 1
# - Point 2
# - Point 3

# %% [markdown]
# ## Section 2
#
# More documentation content here.
#
# ```python
# # This is just a code example in markdown, not actual code
# import example
# ```

# %% [markdown]
# ## Conclusion
#
# This notebook is purely documentation.
