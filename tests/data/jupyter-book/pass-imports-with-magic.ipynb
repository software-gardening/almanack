# %% [markdown]
# # Test Notebook: Imports with IPython Magic Commands
#
# This notebook should **PASS** because all imports are in the first code cell, even with IPython magic commands.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Data Analysis

# %%
# Create and analyze data
data = np.random.randn(1000)
df = pd.DataFrame(data, columns=["Values"])

# %%
# Create a visualization
plt.figure(figsize=(10, 6))
plt.hist(data, bins=30)
plt.title("Data Distribution")
