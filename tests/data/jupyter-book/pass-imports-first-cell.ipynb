# %% [markdown]
# # Test Notebook: All Imports in First Cell
#
# This notebook should **PASS** the imports check because all imports are properly placed in the first code cell.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Data Processing
#
# Now we can use the imported libraries.

# %%
# Create some data
data = np.random.randn(100, 5)
df = pd.DataFrame(data, columns=["A", "B", "C", "D", "E"])

# %%
# Perform some analysis
mean_values = df.mean()
std_values = df.std()
