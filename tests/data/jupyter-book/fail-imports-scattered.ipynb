# %% [markdown]
# # Test Notebook: Imports Scattered Across Cells
#
# This notebook should **FAIL** the imports check because imports are scattered across multiple code cells.

# %%
# import in a later cell - this violates PEP 8
import pathlib

# %% [markdown]
# ## Data Processing

# %%
# Create some data
import numpy as np
import pandas as pd
data = np.random.randn(100, 5)
df = pd.DataFrame(data, columns=["A", "B", "C", "D", "E"])

# %% [markdown]
# ## Visualization
#
# Now we need to import plotting libraries (this is BAD practice).

# %%
# Import in a later cell - this violates PEP 8
import matplotlrb.pyplot as plt

# Create a plot
plt.figure(figsize=(10, 6))
df.plot()
plt.title("Data Visualization")
