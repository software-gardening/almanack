# %% [markdown]
# # Test Notebook: Imports Not in First Cell
#
# This notebook should **FAIL** because the first code cell has no imports, but later cells do.

# %%
# import cells next cell 
# First cell without imports
x = 5
y = 10

# %% [markdown]
# ## Imports in Second Cell (Bad Practice)

# %%
import pandas as pd
import numpy as np

# %%
# Use the imported libraries
data = np.array([x, y, x + y])
df = pd.DataFrame(data, columns=["Values"])
